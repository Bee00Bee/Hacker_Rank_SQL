# %% [markdown]
# ![Screenshot from 2023-01-13 14-13-16.png](attachment:4923d753-b0f1-4db4-b96a-901b79384c1e.png)

# %%
select convert( 
               decimal(12, 4), 
               sqrt( power(min(lat_n)-max(lat_n), 2) + power(min(long_w)-max(long_w), 2) ) 
              )
        from station;
