# %% [markdown]
# ![Screenshot from 2023-01-25 09-47-01.png](attachment:a2fa4f19-a990-406f-ad23-3d8b25d0ffee.png)

# %%
select distinct (city) from station
where city like '[aeiou]%' and city like '%[aeiou]';
