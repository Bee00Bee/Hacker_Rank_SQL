# %% [markdown]
# ![Screenshot from 2022-12-07 13-43-03.png](attachment:5722c6d0-53c3-463e-a4c0-748c281ab868.png)
# ![Screenshot from 2022-12-07 13-43-42.png](attachment:2ca41af2-218d-401c-bf9f-0421fa91c5ae.png)

# %%
select concat(name, '(', substring(occupation, 1, 1), ')') from OCCUPATIONS
order by name

select concat('There are a total of ', count(occupation), ' ' ,lower(occupation), 's.') from occupations
group by occupation
order by occupation
