# %% [markdown]
# ![Screenshot from 2022-12-07 12-40-21.png](attachment:46bbde37-c746-4c95-b99b-1d412a3177eb.png)

# %%
select * from city
where 
    countrycode = 'USA'
    and 
    population > 100000
