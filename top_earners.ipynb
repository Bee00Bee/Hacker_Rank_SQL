# %% [markdown]
# ![Screenshot from 2023-01-13 12-19-51.png](attachment:c9636f15-328d-487f-8bdc-5ada7d4407c6.png)
# ![Screenshot from 2023-01-13 12-20-02.png](attachment:5ba1e88c-b60b-44a2-b227-7a9dc9f8f91c.png)
# ![Screenshot from 2023-01-13 12-20-12.png](attachment:ed1b1a0e-905a-4c72-bc93-22ddb0d4e2fa.png)

# %%
select max(months*salary), count(*) from employee
where months*salary >= (select max(months*salary) from employee);
