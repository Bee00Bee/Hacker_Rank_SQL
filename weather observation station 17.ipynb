# %% [markdown]
# ![Screenshot from 2023-01-13 13-50-24.png](attachment:ebcdb9cc-9b74-477b-8c9a-825351dec789.png)

# %%
select convert(decimal(12, 4), long_w) from station
where lat_n in (select min(lat_n) from station where lat_n > 38.7780);
