# %% [markdown]
# ![Screenshot from 2022-12-07 13-08-20.png](attachment:11549d59-27a4-4414-9328-d4a04d093166.png)

# %%
select case
    when A+B <= C or A+C <=B or B+C<=A then 'Not A Triangle'
    when A=B and B=C then 'Equilateral'
    when A=B or B=C or A=C then 'Isosceles'    
    else 'Scalene'    
    end
from Triangles
